# %%
import matplotlib.pyplot as plt
x = [10,20,30,40,50,60]
y = [70,80,90,100,11,10]
plt.plot(x,y,color ='black', linestyle = '--',linewidth = 6, marker = 's', markersize = 8, markerfacecolor='red')
plt.xlable("pardhu")
plt.ylabel("paila")
plt.title("labelling")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 y = [70,80,90,100,11,10]
#       4 plt.plot(x,y,color ='black', linestyle = '--',linewidth = 6, marker = 's', markersize = 8, markerfacecolor='red')
# ----> 5 plt.xlable("pardhu")
#       6 plt.ylabel("paila")
#       7 plt.title("labelling")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
